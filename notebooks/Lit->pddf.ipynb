# %%
import pandas as pd

df = pd.read_csv('../data/Literature_research_vibrio.csv')
df_cleaned = df.dropna(axis=1, how='all')  # Remove empty columns
df_cleaned.head()
# Out:
#                            Medium  Growth Rate (μ) Doubling Time  \
# 0           BHIN-like (replicate)  2.70 ± 0.03 h⁻¹      15.4 min
# 1  BHIN-like filtered (replicate)  3.54 ± 0.22 h⁻¹       9.4 min
# 2                             LB3         Variable    ~12-15 min
# 3            LBO-like (replicate)         Variable    ~12-15 min
# 4            VN Minimal (aerobic)  1.48 ± 0.06 h⁻¹        28 min
#
#      Final OD₆₀₀       Time Tryptone Yeast Extract Glycerol Glucose NaCl  \
# 0  Not specified  0.5-1.5 h       10             5        -       5   20
# 1  Not specified       ~2 h       10             5        -       5   20
# 2  Not specified  Overnight       10             5        -       -   30
# 3  Not specified  Overnight       10             5        -       -   20
# 4          ~15.7        5 h        -             -        -      10   15
#
#   MgSO₄  KCl (NH₄)₂SO₄ K₂HPO₄ KH₂PO₄ MOPS CaCl₂ Trace Metals  \
# 0     -    -         -    2.5      -    -     -            -
# 1     -    -         -    2.5      -    -     -            -
# 2     -    -         -      -      -    -     -            -
# 3     2  0.5         -      -      -    -   0.1            -
# 4  0.25    -         5      1      1    -  0.01          Yes
#
#                           Notes        Source
# 0     Complex medium substitute  Hoffart 2017
# 1    Filter sterilize (0.22 μm)  Hoffart 2017
# 2                 ✓ EXACT MATCH   Eilers 2016
# 3     Ocean salts approximation   Eilers 2016
# 4  ✓ EXACT MATCH - Best defined  Hoffart 2017

# %%
# Remove Doubling Time and Growth Rate columns
df_cleaned = df_cleaned.drop(columns=['Doubling Time', 'Growth Rate (μ)'])
df_cleaned.head()
# Out:
#                            Medium    Final OD₆₀₀       Time Tryptone  \
# 0           BHIN-like (replicate)  Not specified  0.5-1.5 h       10
# 1  BHIN-like filtered (replicate)  Not specified       ~2 h       10
# 2                             LB3  Not specified  Overnight       10
# 3            LBO-like (replicate)  Not specified  Overnight       10
# 4            VN Minimal (aerobic)          ~15.7        5 h        -
#
#   Yeast Extract Glycerol Glucose NaCl MgSO₄  KCl (NH₄)₂SO₄ K₂HPO₄ KH₂PO₄ MOPS  \
# 0             5        -       5   20     -    -         -    2.5      -    -
# 1             5        -       5   20     -    -         -    2.5      -    -
# 2             5        -       -   30     -    -         -      -      -    -
# 3             5        -       -   20     2  0.5         -      -      -    -
# 4             -        -      10   15  0.25    -         5      1      1    -
#
#   CaCl₂ Trace Metals                         Notes        Source
# 0     -            -     Complex medium substitute  Hoffart 2017
# 1     -            -    Filter sterilize (0.22 μm)  Hoffart 2017
# 2     -            -                 ✓ EXACT MATCH   Eilers 2016
# 3   0.1            -     Ocean salts approximation   Eilers 2016
# 4  0.01          Yes  ✓ EXACT MATCH - Best defined  Hoffart 2017

# %%
# Add HCl and NaOH columns (not present in the literature data, filled with '-')
df_cleaned['HCl'] = '-'
df_cleaned['NaOH'] = '-'
df_cleaned.columns

# %%
# Replace all '-' values with 0
# Exclude non-numeric columns like 'Medium', 'Notes', 'Source', 'Final OD₆₀₀', 'Time'
exclude_cols = ['Medium', 'Notes', 'Source', 'Final OD₆₀₀', 'Time', 'Trace Metals']
numeric_cols = [col for col in df_cleaned.columns if col not in exclude_cols]

# Replace '-' with 0 in all numeric columns
for col in numeric_cols:
    df_cleaned[col] = df_cleaned[col].replace('-', 0)
    # Also handle any other non-numeric values
    df_cleaned[col] = pd.to_numeric(df_cleaned[col], errors='coerce').fillna(0)

df_cleaned.head()
# Out:
# /var/folders/9g/q_w246652jsfrgt3684zkxf40000gn/T/ipykernel_12654/399086202.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_cleaned[col] = df_cleaned[col].replace('-', 0)
#                            Medium    Final OD₆₀₀       Time  Tryptone  \
# 0           BHIN-like (replicate)  Not specified  0.5-1.5 h        10
# 1  BHIN-like filtered (replicate)  Not specified       ~2 h        10
# 2                             LB3  Not specified  Overnight        10
# 3            LBO-like (replicate)  Not specified  Overnight        10
# 4            VN Minimal (aerobic)          ~15.7        5 h         0
#
#    Yeast Extract  Glycerol  Glucose  NaCl  MgSO₄  KCl  (NH₄)₂SO₄  K₂HPO₄  \
# 0            5.0       0.0      5.0  20.0   0.00  0.0        0.0     2.5
# 1            5.0       0.0      5.0  20.0   0.00  0.0        0.0     2.5
# 2            5.0       0.0      0.0  30.0   0.00  0.0        0.0     0.0
# 3            5.0       0.0      0.0  20.0   2.00  0.5        0.0     0.0
# 4            0.0       0.0     10.0  15.0   0.25  0.0        5.0     1.0
#
#    KH₂PO₄  MOPS  CaCl₂ Trace Metals                         Notes  \
# 0     0.0     0   0.00            -     Complex medium substitute
# 1     0.0     0   0.00            -    Filter sterilize (0.22 μm)
# 2     0.0     0   0.00            -                 ✓ EXACT MATCH
# 3     0.0     0   0.10            -     Ocean salts approximation
# 4     1.0     0   0.01          Yes  ✓ EXACT MATCH - Best defined
#
#          Source  HCl  NaOH
# 0  Hoffart 2017    0     0
# 1  Hoffart 2017    0     0
# 2   Eilers 2016    0     0
# 3   Eilers 2016    0     0
# 4  Hoffart 2017    0     0

# %%
# Drop rows where Final OD₆₀₀ is 0 or not specified
# First convert Final OD₆₀₀ to numeric
df_cleaned['Final OD₆₀₀_num'] = pd.to_numeric(df_cleaned['Final OD₆₀₀'].astype(str).str.replace('~', '').str.replace('Not specified', ''), errors='coerce')

# Drop rows where Final OD₆₀₀ is 0 or NaN
df_cleaned = df_cleaned[df_cleaned['Final OD₆₀₀_num'] > 0]
df_cleaned = df_cleaned.drop(columns=['Final OD₆₀₀_num'])

print(f"Rows remaining: {len(df_cleaned)}")
df_cleaned
# Out:
# Rows remaining: 6
#                          Medium Final OD₆₀₀   Time  Tryptone  Yeast Extract  \
# 4          VN Minimal (aerobic)       ~15.7    5 h         0            0.0
# 5   VN Minimal (anaerobic-like)        ~4.4    7 h         0            0.0
# 8          MSM Fed-batch (30°C)        ~204   12 h         0            0.0
# 9          MSM Fed-batch (37°C)        ~148   12 h         0            0.0
# 13        Anaerobic-like (MOPS)        ~5.5  216 h         0            0.0
# 14             VN Resting cells         ~74    2 h         0            0.0
#
#     Glycerol  Glucose  NaCl  MgSO₄  KCl  (NH₄)₂SO₄  K₂HPO₄  KH₂PO₄  MOPS  \
# 4        0.0     10.0  15.0   0.25  0.0        5.0     1.0     1.0     0
# 5        0.0     10.0  15.0   0.25  0.0        5.0     1.0     1.0     0
# 8        0.0      0.0  17.0   0.50  0.0        5.0     2.0     2.0     0
# 9        0.0      0.0  17.0   0.50  0.0        5.0     2.0     2.0     0
# 13       0.0     10.0  15.0   0.50  0.0        5.0     2.0     2.0    10
# 14       0.0     42.5  15.0   0.25  0.0        5.0     1.0     1.0     0
#
#     CaCl₂ Trace Metals                                   Notes        Source  \
# 4    0.01          Yes            ✓ EXACT MATCH - Best defined  Hoffart 2017
# 5    0.01          Yes                     No NaHCO₃ available  Hoffart 2017
# 8    0.02          Yes         High cell density - glucose fed     Fink 2021
# 9    0.02          Yes         High cell density - glucose fed     Fink 2021
# 13   0.02          Yes                  MOPS buffer substitute  Gemünde 2023
# 14   0.01          Yes  ✓ EXACT - High glucose, 20 g/L biomass  Hoffart 2017
#
#     HCl  NaOH
# 4     0     0
# 5     0     0
# 8     0     0
# 9     0     0
# 13    0     0
# 14    0     0

# %%
# Remove Notes and Source columns
df_cleaned = df_cleaned.drop(columns=['Notes', 'Source'])
df_cleaned.head()
# Out:
#                          Medium Final OD₆₀₀   Time  Tryptone  Yeast Extract  \
# 4          VN Minimal (aerobic)       ~15.7    5 h         0            0.0
# 5   VN Minimal (anaerobic-like)        ~4.4    7 h         0            0.0
# 8          MSM Fed-batch (30°C)        ~204   12 h         0            0.0
# 9          MSM Fed-batch (37°C)        ~148   12 h         0            0.0
# 13        Anaerobic-like (MOPS)        ~5.5  216 h         0            0.0
#
#     Glycerol  Glucose  NaCl  MgSO₄  KCl  (NH₄)₂SO₄  K₂HPO₄  KH₂PO₄  MOPS  \
# 4        0.0     10.0  15.0   0.25  0.0        5.0     1.0     1.0     0
# 5        0.0     10.0  15.0   0.25  0.0        5.0     1.0     1.0     0
# 8        0.0      0.0  17.0   0.50  0.0        5.0     2.0     2.0     0
# 9        0.0      0.0  17.0   0.50  0.0        5.0     2.0     2.0     0
# 13       0.0     10.0  15.0   0.50  0.0        5.0     2.0     2.0    10
#
#     CaCl₂ Trace Metals  HCl  NaOH
# 4    0.01          Yes    0     0
# 5    0.01          Yes    0     0
# 8    0.02          Yes    0     0
# 9    0.02          Yes    0     0
# 13   0.02          Yes    0     0

# %%
# Remove Medium column
df_cleaned = df_cleaned.drop(columns=['Medium'])
df_cleaned.head()
# Out:
#    Final OD₆₀₀   Time  Tryptone  Yeast Extract  Glycerol  Glucose  NaCl  \
# 4        ~15.7    5 h         0            0.0       0.0     10.0  15.0
# 5         ~4.4    7 h         0            0.0       0.0     10.0  15.0
# 8         ~204   12 h         0            0.0       0.0      0.0  17.0
# 9         ~148   12 h         0            0.0       0.0      0.0  17.0
# 13        ~5.5  216 h         0            0.0       0.0     10.0  15.0
#
#     MgSO₄  KCl  (NH₄)₂SO₄  K₂HPO₄  KH₂PO₄  MOPS  CaCl₂ Trace Metals  HCl  NaOH
# 4    0.25  0.0        5.0     1.0     1.0     0   0.01          Yes    0     0
# 5    0.25  0.0        5.0     1.0     1.0     0   0.01          Yes    0     0
# 8    0.50  0.0        5.0     2.0     2.0     0   0.02          Yes    0     0
# 9    0.50  0.0        5.0     2.0     2.0     0   0.02          Yes    0     0
# 13   0.50  0.0        5.0     2.0     2.0    10   0.02          Yes    0     0

# %%
# Create a growth rate column (Final OD₆₀₀ / Time)
# Convert Final OD₆₀₀ to numeric
df_cleaned['Final OD₆₀₀_num'] = pd.to_numeric(df_cleaned['Final OD₆₀₀'].astype(str).str.replace('~', ''), errors='coerce')

# Convert Time to numeric hours (extract numbers and assume hours)
# Handle cases like "5 h", "12 h", "~2 h", "Overnight", etc.
df_cleaned['Time_num'] = df_cleaned['Time'].astype(str).str.extract(r'(\d+\.?\d*)').astype(float)

# For Time values like "Overnight" or "Several h", set a default value (e.g., 12 hours)
df_cleaned.loc[df_cleaned['Time'].str.contains('Overnight', case=False, na=False), 'Time_num'] = 12
df_cleaned.loc[df_cleaned['Time'].str.contains('Several', case=False, na=False), 'Time_num'] = 24

# Calculate growth rate
df_cleaned['growth rate'] = df_cleaned['Final OD₆₀₀_num'] / df_cleaned['Time_num']

# Remove temporary columns
df_cleaned = df_cleaned.drop(columns=['Final OD₆₀₀_num', 'Time_num'])

df_cleaned.head()
# Out:
#    Final OD₆₀₀   Time  Tryptone  Yeast Extract  Glycerol  Glucose  NaCl  \
# 4        ~15.7    5 h         0            0.0       0.0     10.0  15.0
# 5         ~4.4    7 h         0            0.0       0.0     10.0  15.0
# 8         ~204   12 h         0            0.0       0.0      0.0  17.0
# 9         ~148   12 h         0            0.0       0.0      0.0  17.0
# 13        ~5.5  216 h         0            0.0       0.0     10.0  15.0
#
#     MgSO₄  KCl  (NH₄)₂SO₄  K₂HPO₄  KH₂PO₄  MOPS  CaCl₂ Trace Metals  HCl  \
# 4    0.25  0.0        5.0     1.0     1.0     0   0.01          Yes    0
# 5    0.25  0.0        5.0     1.0     1.0     0   0.01          Yes    0
# 8    0.50  0.0        5.0     2.0     2.0     0   0.02          Yes    0
# 9    0.50  0.0        5.0     2.0     2.0     0   0.02          Yes    0
# 13   0.50  0.0        5.0     2.0     2.0    10   0.02          Yes    0
#
#     NaOH  growth rate
# 4      0     3.140000
# 5      0     0.628571
# 8      0    17.000000
# 9      0    12.333333
# 13     0     0.025463

# %%
# Remove Final OD₆₀₀ and Time columns
df_cleaned = df_cleaned.drop(columns=['Final OD₆₀₀', 'Time'])
df_cleaned.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 2
#       1 # Remove Final OD₆₀₀ and Time columns
# ----> 2 df_cleaned = df_cleaned.drop(columns=['Final OD₆₀₀', 'Time'])
#       3 df_cleaned.head()
#
# File ~/Desktop/Hackathon_monomer/monomer_hackathon_2025/.venv/lib/python3.12/site-packages/pandas/core/frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# File ~/Desktop/Hackathon_monomer/monomer_hackathon_2025/.venv/lib/python3.12/site-packages/pandas/core/generic.py:4810, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4808 for axis, labels in axes.items():
#    4809     if labels is not None:
# -> 4810         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4812 if inplace:
#    4813     self._update_inplace(obj)
#
# File ~/Desktop/Hackathon_monomer/monomer_hackathon_2025/.venv/lib/python3.12/site-packages/pandas/core/generic.py:4852, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4850         new_axis = axis.drop(labels, level=level, errors=errors)
#    4851     else:
# -> 4852         new_axis = axis.drop(labels, errors=errors)
#    4853     indexer = axis.get_indexer(new_axis)
#    4855 # Case for non-unique axis
#    4856 else:
#
# File ~/Desktop/Hackathon_monomer/monomer_hackathon_2025/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['Final OD₆₀₀', 'Time'] not found in axis"

# %%
# Add 'cell_dilution' column with value 1 for every row if it doesn't exist
if 'cell_dilution' not in df_cleaned.columns:
    df_cleaned['cell_dilution'] = 1.0

# %%
df_cleaned.head()
# Out:
#     Tryptone  Yeast Extract  Glycerol  Glucose  NaCl  MgSO₄  KCl  (NH₄)₂SO₄  \
# 4          0            0.0       0.0     10.0  15.0   0.25  0.0        5.0
# 5          0            0.0       0.0     10.0  15.0   0.25  0.0        5.0
# 8          0            0.0       0.0      0.0  17.0   0.50  0.0        5.0
# 9          0            0.0       0.0      0.0  17.0   0.50  0.0        5.0
# 13         0            0.0       0.0     10.0  15.0   0.50  0.0        5.0
#
#     K₂HPO₄  KH₂PO₄  MOPS  CaCl₂ Trace Metals  HCl  NaOH  growth rate  \
# 4      1.0     1.0     0   0.01          Yes    0     0     3.140000
# 5      1.0     1.0     0   0.01          Yes    0     0     0.628571
# 8      2.0     2.0     0   0.02          Yes    0     0    17.000000
# 9      2.0     2.0     0   0.02          Yes    0     0    12.333333
# 13     2.0     2.0    10   0.02          Yes    0     0     0.025463
#
#     cell_dilution
# 4             1.0
# 5             1.0
# 8             1.0
# 9             1.0
# 13            1.0

# %%
# Save the cleaned dataframe as CSV
df_cleaned.to_csv('../data/litterature_research_cleanup.csv', index=False)
print("DataFrame saved to '../data/litterature_research_cleanup.csv'")
print(f"Shape: {df_cleaned.shape}")
# Out:
# DataFrame saved to '../data/litterature_research_cleanup.csv'
# Shape: (6, 17)
